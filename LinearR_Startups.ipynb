# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('50_Startups_LR.csv')
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07        252664.93  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04
# 16   78013.11       121597.55        264346.06  California  126992.93
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York  122776.86
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 22   73994.56       122782.75        303319.26     Florida  110352.25
# 23   67532.53       105751.03        304768.73     Florida  108733.99
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 25   64664.71       139553.16        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York  105008.31
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 32   63408.86       129219.61         46085.25  California   97427.84
# 33   55493.95       103057.49        214634.81     Florida   96778.92
# 34   46426.07       157693.92        210797.67  California   96712.80
# 35   46014.02        85047.44        205517.64    New York   96479.51
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51        82982.09        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67  California   78239.91
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 42   23640.93        96189.63        148001.11  California   71498.49
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California   65200.33
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 47       0.00       135426.92             0.00  California   42559.73
# 48     542.05        51743.15             0.00    New York   35673.41
# 49       0.00       116983.80         45173.06  California   14681.40

# %%
data_new=data.rename(columns={'R&D Spend': 'R&D_Spend','Marketing Spend':'Marketing_Spend'})
data_new
# Out:
#     R&D_Spend  Administration  Marketing_Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07        252664.93  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04
# 16   78013.11       121597.55        264346.06  California  126992.93
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York  122776.86
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 22   73994.56       122782.75        303319.26     Florida  110352.25
# 23   67532.53       105751.03        304768.73     Florida  108733.99
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 25   64664.71       139553.16        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York  105008.31
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 32   63408.86       129219.61         46085.25  California   97427.84
# 33   55493.95       103057.49        214634.81     Florida   96778.92
# 34   46426.07       157693.92        210797.67  California   96712.80
# 35   46014.02        85047.44        205517.64    New York   96479.51
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51        82982.09        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67  California   78239.91
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 42   23640.93        96189.63        148001.11  California   71498.49
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California   65200.33
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 47       0.00       135426.92             0.00  California   42559.73
# 48     542.05        51743.15             0.00    New York   35673.41
# 49       0.00       116983.80         45173.06  California   14681.40

# %%
## since the data is continuous, we will use LINEAR REGRESSION

# %%
data_new.head()
# Out:
#    R&D_Spend  Administration  Marketing_Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data_new.tail()
# Out:
#     R&D_Spend  Administration  Marketing_Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
data_new.shape
# Out:
# (50, 5)

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D_Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing_Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data_new.describe() ## since STD !=0, so there is no constant features in the data set
# Out:
#            R&D_Spend  Administration  Marketing_Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
data_new.median()
# Out:
# R&D_Spend           73051.080
# Administration     122699.795
# Marketing_Spend    212716.240
# Profit             107978.190
# dtype: float64

# %%
data_new.mode()
# Out:
#     R&D_Spend  Administration  Marketing_Spend       State     Profit
# 0         0.0        51283.14              0.0  California   14681.40
# 1         NaN        51743.15              NaN    New York   35673.41
# 2         NaN        65947.93              NaN         NaN   42559.73
# 3         NaN        82982.09              NaN         NaN   49490.75
# 4         NaN        84710.77              NaN         NaN   64926.08
# 5         NaN        85047.44              NaN         NaN   65200.33
# 6         NaN        91391.77              NaN         NaN   69758.98
# 7         NaN        91790.61              NaN         NaN   71498.49
# 8         NaN        96189.63              NaN         NaN   77798.83
# 9         NaN        99281.34              NaN         NaN   78239.91
# 10        NaN        99814.71              NaN         NaN   81005.76
# 11        NaN       101145.55              NaN         NaN   81229.06
# 12        NaN       103057.49              NaN         NaN   89949.14
# 13        NaN       105751.03              NaN         NaN   90708.19
# 14        NaN       108679.17              NaN         NaN   96479.51
# 15        NaN       110594.11              NaN         NaN   96712.80
# 16        NaN       113867.30              NaN         NaN   96778.92
# 17        NaN       114175.79              NaN         NaN   97427.84
# 18        NaN       115641.28              NaN         NaN   97483.56
# 19        NaN       115816.21              NaN         NaN   99937.59
# 20        NaN       116983.80              NaN         NaN  101004.64
# 21        NaN       118546.05              NaN         NaN  103282.38
# 22        NaN       118671.85              NaN         NaN  105008.31
# 23        NaN       121597.55              NaN         NaN  105733.54
# 24        NaN       122616.84              NaN         NaN  107404.34
# 25        NaN       122782.75              NaN         NaN  108552.04
# 26        NaN       124153.04              NaN         NaN  108733.99
# 27        NaN       127056.21              NaN         NaN  110352.25
# 28        NaN       127320.38              NaN         NaN  111313.02
# 29        NaN       127382.30              NaN         NaN  118474.03
# 30        NaN       127864.55              NaN         NaN  122776.86
# 31        NaN       129219.61              NaN         NaN  124266.90
# 32        NaN       135426.92              NaN         NaN  125370.37
# 33        NaN       135495.07              NaN         NaN  126992.93
# 34        NaN       136897.80              NaN         NaN  129917.04
# 35        NaN       139553.16              NaN         NaN  132602.65
# 36        NaN       144135.98              NaN         NaN  134307.35
# 37        NaN       145077.58              NaN         NaN  141585.52
# 38        NaN       145530.06              NaN         NaN  144259.40
# 39        NaN       147198.87              NaN         NaN  146121.95
# 40        NaN       148718.95              NaN         NaN  149759.96
# 41        NaN       151377.59              NaN         NaN  152211.77
# 42        NaN       152701.92              NaN         NaN  155752.60
# 43        NaN       153032.06              NaN         NaN  156122.51
# 44        NaN       153514.11              NaN         NaN  156991.12
# 45        NaN       153773.43              NaN         NaN  166187.94
# 46        NaN       154806.14              NaN         NaN  182901.99
# 47        NaN       156547.42              NaN         NaN  191050.39
# 48        NaN       157693.92              NaN         NaN  191792.06
# 49        NaN       182645.56              NaN         NaN  192261.83

# %%
data_new.State.unique() ## this column does not have unique feature so we don't dropped this column
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
data_new.isnull().sum() ## here we don't have MISSING VALUES
# Out:
# R&D_Spend          0
# Administration     0
# Marketing_Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
cor=data_new.corr()
sns.heatmap(data_new.drop('Profit',axis=1).corr(),annot=True)

## no features are highly correlated hence we dont remove any feature
# Out:
# <AxesSubplot:>

# %%
## to check linear relationship between input variables and target variables using scatter plot

plt.figure(figsize=(20,15), facecolor='white') #To set canvas 
plotnumber=1
for column in data_new:#accessing the columns 
    if plotnumber<=3:
        ax = plt.subplot(3,3,plotnumber)#plotting 3 graph
        sns.scatterplot(x=data_new[column].dropna(axis=0),y=data_new.Profit) # scatter plot
        plt.xlabel(column,fontsize=10)
        plt.ylabel('Profit',fontsize=10)
        plotnumber+=1#counter increment
#plt.show()
plt.tight_layout()

# Linear Relationship exist between input variable (R&D_Spend) the Target Variable('Profit')

# %%
## to check linear relationship between input variables and target variables using line plot (for Continuous data)

plt.figure(figsize=(20,15), facecolor='white') #To set canvas 
plotnumber=1
for column in data_new:#accessing the columns 
    if plotnumber<=3:
        ax =plt.subplot(3,3,plotnumber)#plotting 3 graph
        sns.lineplot(x=data_new[column].dropna(axis=0),y=data_new.Profit) # scatter plot
        plt.xlabel(column,fontsize=10)
        plt.ylabel('Profit',fontsize=10)
        plotnumber+=1#counter increment
#plt.show()
plt.tight_layout()

## Linear Relationship exist between input variable (R&D_Spend) the Target Variable('Profit')

# %%
drop_data=data_new.drop('State', axis=1)
drop_data
# Out:
#     R&D_Spend  Administration  Marketing_Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# 15  114523.61       122616.84        261776.23  129917.04
# 16   78013.11       121597.55        264346.06  126992.93
# 17   94657.16       145077.58        282574.31  125370.37
# 18   91749.16       114175.79        294919.57  124266.90
# 19   86419.70       153514.11             0.00  122776.86
# 20   76253.86       113867.30        298664.47  118474.03
# 21   78389.47       153773.43        299737.29  111313.02
# 22   73994.56       122782.75        303319.26  110352.25
# 23   67532.53       105751.03        304768.73  108733.99
# 24   77044.01        99281.34        140574.81  108552.04
# 25   64664.71       139553.16        137962.62  107404.34
# 26   75328.87       144135.98        134050.07  105733.54
# 27   72107.60       127864.55        353183.81  105008.31
# 28   66051.52       182645.56        118148.20  103282.38
# 29   65605.48       153032.06        107138.38  101004.64
# 30   61994.48       115641.28         91131.24   99937.59
# 31   61136.38       152701.92         88218.23   97483.56
# 32   63408.86       129219.61         46085.25   97427.84
# 33   55493.95       103057.49        214634.81   96778.92
# 34   46426.07       157693.92        210797.67   96712.80
# 35   46014.02        85047.44        205517.64   96479.51
# 36   28663.76       127056.21        201126.82   90708.19
# 37   44069.95        51283.14        197029.42   89949.14
# 38   20229.59        65947.93        185265.10   81229.06
# 39   38558.51        82982.09        174999.30   81005.76
# 40   28754.33       118546.05        172795.67   78239.91
# 41   27892.92        84710.77        164470.71   77798.83
# 42   23640.93        96189.63        148001.11   71498.49
# 43   15505.73       127382.30         35534.17   69758.98
# 44   22177.74       154806.14         28334.72   65200.33
# 45    1000.23       124153.04          1903.93   64926.08
# 46    1315.46       115816.21        297114.46   49490.75
# 47       0.00       135426.92             0.00   42559.73
# 48     542.05        51743.15             0.00   35673.41
# 49       0.00       116983.80         45173.06   14681.40

# %%
## Checking for outliers in data set using BOX plot (for continuous data)
plt.figure(figsize=(10,15), facecolor='white') #To set canvas 
plotnumber=1
for column in drop_data:#accessing the columns 
    if plotnumber<=4:
        ax = plt.subplot(3,3,plotnumber)#plotting 4 graph
        sns.boxplot(drop_data[column]) # BOXplot
        plt.title(column,fontsize=10)
        plotnumber+=1#counter increment
#plt.show()
plt.tight_layout()

## Profit has 1 outlier

# %%
## Skweness and Kurtosis test i.e check for normality
##Skweness and Kurtosis test i.e check for normality
## Skewness is used to measure the level of asymmetry in our graph.
## It is the measure of asymmetry that occurs when our data deviates from the norm
## Skewness is used to denote the horizontal pull on the data.
## -0.5 and 0.5, the distribution of the value is almost symmetrical
## -1 and -0.5, the data is negatively skewed,The skewness is moderate.(Mode > Median > Mean.)
##  0.5 to 1, the data is positively skewed. The skewness is moderate.(Mean > Median > Mode)
## If the skewness is lower than -1 (negatively skewed) or greater than 1 (positively skewed), the data is highly skewed
## negative skewness means the tail of the distribution is longer towards the left hand side of the curve
## positive Skewness means the tail of the distribution is longer towards the right hand side of the curve

from scipy.stats import skew
for column in drop_data:
    print('skew of ',column, skew(drop_data[column]) )
    
##   R&D is almost symmetrical
##   Administration is almost symmetrical
##   Marketing_Spend is almost Symmetrical
##   Profit is almost symmetrical
# Out:
# skew of  R&D_Spend 0.15904052321503395
# skew of  Administration -0.4742300698920047
# skew of  Marketing_Spend -0.04506631617666136
# skew of  Profit 0.02258638356958943

# %%
# Kurtosis is used to find the presence of outliers in our data. It gives us the total degree of outliers present.
# Kurtosis is used to find the vertical pull or the peak's height. 
## A kurtosis greater than 3 will indicate Positive Kurtosis.
## For Positive Kurtosis, the values of kurtosis will range from 3 to infinity.
## A kurtosis less than 3 will mean a negative kurtosis.
## For Negative Kurtosis, the values kurtosis will range from  -2 to infinity.
#  The greater the value of kurtosis, the higher the peak. 

from scipy import stats
for column in drop_data:
    print('kurtosis of',column,stats.kurtosis(drop_data[column]))
    
##   R&D is has Negative Kurtosis
##   Administration Negative Kurtosis 
##   Marketing_Spend is Negative Kurtosis
##   Profit is almost Negative Kurtosis
# Out:
# kurtosis of R&D_Spend -0.8050676431519039
# kurtosis of Administration 0.08553840791984113
# kurtosis of Marketing_Spend -0.7240327111087308
# kurtosis of Profit -0.17529637679752152

# %%
## to check skewness and kurtosis between input variables and target variables using distribution plot (for Continuous data)

##(mode is most frequent value of the entire feature column)

## positive Skewness means the tail of the distribution is longer towards the right hand side of the curve
## the mean is the largest, while the mode is the smallest.

## IN Normal distribution(symmetric), tail of the distribution is equal to both left and Right hand side of the curve
## The mean median  mode are equal

## Negative skewness means the tail of the distribution is longer towards the left hand side of the curve
## The mean is less than the median, and they are both less than the mode

plt.figure(figsize=(10,15), facecolor='white') #To set canvas 
plotnumber=1
for column in drop_data:#accessing the columns 
    if plotnumber<=4:
        ax = plt.subplot(3,3,plotnumber)#plotting 4 graph
        sns.distplot(drop_data[column]) # BOXplot
        plt.title(column,fontsize=10)
        plotnumber+=1#counter increment
#plt.show()
plt.tight_layout()

##   R&D is almost Positive Skewness
##   Administration is Negative Skewness
##   Marketing_Spend is Negative Skewness
##   Profit is Positive Skewness

# %%
## Pie plot for categorical data

data_new.State.value_counts()
# Out:
# New York      17
# California    17
# Florida       16
# Name: State, dtype: int64

# %%
pie_list=[17,17,16]
plt.pie(pie_list,labels=['New York','California','Florida'],autopct='%.2f')
plt.show()

# %%
sns.countplot(x='State',data=data_new)
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %%
## Standard Scaling 
from sklearn.preprocessing import StandardScaler
sc=StandardScaler() ## object creation
drop_data[['R&D_Spend','Administration','Marketing_Spend','Profit']]= sc.fit_transform(drop_data[['R&D_Spend','Administration','Marketing_Spend','Profit']])
drop_data
# Out:
#     R&D_Spend  Administration  Marketing_Spend    Profit
# 0    2.016411        0.560753         2.153943  2.011203
# 1    1.955860        1.082807         1.923600  1.999430
# 2    1.754364       -0.728257         1.626528  1.980842
# 3    1.554784       -0.096365         1.422210  1.776627
# 4    1.504937       -1.079919         1.281528  1.357740
# 5    1.279800       -0.776239         1.254210  1.127250
# 6    1.340066        0.932147        -0.688150  1.105481
# 7    1.245057        0.871980         0.932186  1.096210
# 8    1.030369        0.986952         0.830887  1.007470
# 9    1.091819       -0.456640         0.776107  0.946022
# 10   0.620398       -0.387599         0.149807  0.854847
# 11   0.593085       -1.065540         0.319834  0.808168
# 12   0.443260        0.215449         0.320617  0.741155
# 13   0.402078        0.510179         0.343957  0.558750
# 14   1.017181        1.269199         0.375742  0.516026
# 15   0.897913        0.045868         0.419219  0.448720
# 16   0.094441        0.009118         0.440446  0.375436
# 17   0.460720        0.855666         0.591017  0.334771
# 18   0.396725       -0.258465         0.692992  0.307116
# 19   0.279442        1.159837        -1.743127  0.269773
# 20   0.055726       -0.269588         0.723926  0.161935
# 21   0.102724        1.169186         0.732788 -0.017534
# 22   0.006007        0.051850         0.762376 -0.041613
# 23  -0.136201       -0.562211         0.774349 -0.082169
# 24   0.073115       -0.795469        -0.581939 -0.086729
# 25  -0.199312        0.656489        -0.603517 -0.115493
# 26   0.035370        0.821718        -0.635835 -0.157367
# 27  -0.035519        0.235069         1.174271 -0.175542
# 28  -0.168793        2.210141        -0.767189 -0.218798
# 29  -0.178609        1.142457        -0.858134 -0.275882
# 30  -0.258074       -0.205629        -0.990357 -0.302625
# 31  -0.276958        1.130554        -1.014419 -0.364127
# 32  -0.226949        0.283924        -1.362450 -0.365524
# 33  -0.401129       -0.659324         0.029817 -0.381787
# 34  -0.600682        1.310535        -0.001879 -0.383444
# 35  -0.609750       -1.308658        -0.045493 -0.389291
# 36  -0.991570        0.205925        -0.081763 -0.533932
# 37  -0.652532       -2.525994        -0.115608 -0.552955
# 38  -1.177178       -1.997270        -0.212785 -0.771497
# 39  -0.773820       -1.383122        -0.297583 -0.777094
# 40  -0.989577       -0.100900        -0.315786 -0.846411
# 41  -1.008534       -1.320796        -0.384552 -0.857466
# 42  -1.102106       -0.906938        -0.520596 -1.015365
# 43  -1.281134        0.217682        -1.449605 -1.058960
# 44  -1.134305        1.206419        -1.509074 -1.173209
# 45  -1.600350        0.101254        -1.727400 -1.180082
# 46  -1.593413       -0.199322         0.711122 -1.566922
# 47  -1.622362        0.507722        -1.743127 -1.740627
# 48  -1.610433       -2.509409        -1.743127 -1.913212
# 49  -1.622362       -0.157226        -1.369985 -2.439313

# %%
X=drop_data.iloc[:,:-1]
y=drop_data.Profit

# %%
X.head()
# Out:
#    R&D_Spend  Administration  Marketing_Spend
# 0   2.016411        0.560753         2.153943
# 1   1.955860        1.082807         1.923600
# 2   1.754364       -0.728257         1.626528
# 3   1.554784       -0.096365         1.422210
# 4   1.504937       -1.079919         1.281528

# %%
y.head()
# Out:
# 0    2.011203
# 1    1.999430
# 2    1.980842
# 3    1.776627
# 4    1.357740
# Name: Profit, dtype: float64

# %%
# splitting training data and test data

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=10,test_size=0.3)

# %%
# model learning

from sklearn.linear_model import LinearRegression
LR=LinearRegression() ##creating the model
LR.fit(X_train,y_train) ## learning the model
y_train_predict=LR.predict(X_train) ## predicting the training output
y_test_predict=LR.predict(X_test) ## pedicting the test data output

# %%
y_train_predict
# Out:
# array([ 0.13252475, -0.56589787,  0.0409001 ,  0.39009524, -0.33800209,
#         1.87713239,  0.40434473, -0.55077927, -1.57511748, -0.03101357,
#         1.22030325,  0.36973627,  0.0467659 ,  0.10423566,  0.44118099,
#         0.9226176 ,  1.42301477, -0.94759524, -0.37296972,  0.00444146,
#         0.53627999, -1.08628131,  0.10149424, -1.58903427, -1.38604172,
#        -1.56827972,  0.96820825, -1.26894552, -0.23839117, -0.23843711,
#        -0.22126241,  1.94778623,  0.81760927, -0.90750169,  1.0169159 ])

# %%
y_test_predict
# Out:
# array([-0.61112019, -0.0802301 , -1.14085741, -1.0408089 , -1.59537995,
#         0.08782576,  1.47951756, -0.32123458,  1.16741729,  1.13056156,
#        -0.73150147,  1.67223826, -0.92375164, -0.32070503,  0.54886269])

# %% [markdown]
# ## Evaluation of metrics

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
##  for test data

R2_score_test=r2_score(y_test,y_test_predict)
print('r2 score for test data =',R2_score_test)
# Out:
# r2 score for test data = 0.981491312159712

# %%
mse_test=mean_squared_error(y_test,y_test_predict)
print('MSE for test data =',mse_test)
# Out:
# MSE for test data = 0.021661439251885187

# %%
import numpy as np
rmse_test=np.sqrt(mse_test)
print('RMSE for test data =',rmse_test)
# Out:
# RMSE for test data = 0.14717825672253762

# %%
mae_test=mean_absolute_error(y_test,y_test_predict)
print('MAE for test data =',mae_test)
# Out:
# MAE for test data = 0.10210697728521684

# %%
X_test.shape ## gives no of records for test data
# Out:
# (15, 3)

# %%
## Adjusted R2 Score

adjusted_r2_test=1-(1-0.981491312159712)*(15-1)/(15-3-1)  ## adjusted_r2_score=[1-(1-r2_score)(N-1)]/(N-P-1)
print('Adjusted r2 score for test data = ',adjusted_r2_test)  ## N=total no of records, P= No of input columns
# Out:
# Adjusted r2 score for test data =  0.9764434882032698

# %% [markdown]
# ####  since r2 score of test data is 98.14%, model performance is very good for testing data
# ####  since there is very less difference in R2 score and Adjusted R2 score in test data so there is no unimportant features

# %%
##  for training data
R2_score_train=r2_score(y_train,y_train_predict)
print('r2 score for train data =',R2_score_train)
# Out:
# r2 score for train data = 0.9320370380252421

# %%
mse_train=mean_squared_error(y_train,y_train_predict)
print('MSE for train data =',mse_train)
# Out:
# MSE for train data = 0.0629988392389642

# %%
rmse_train=np.sqrt(mse_train)
print('RMSE for train data =',rmse_train)
# Out:
# RMSE for train data = 0.2509956956582407

# %%
mae_train=mean_absolute_error(y_train,y_train_predict)
print('MAE for train data =',mae_train)
# Out:
# MAE for train data = 0.1894297460783236

# %%
X_train.shape ## gives no of records for training data
# Out:
# (35, 3)

# %%
## Adjusted R2 Score

adjusted_r2_train=1-(1-0.9320370380252421)*(35-1)/(35-3-1)  ## adjusted_r2_score=[1-(1-r2_score)(N-1)]/(N-P-1)
print('Adjusted r2 score for training data = ',adjusted_r2_train)  ## N=total no of records, P= No of input columns
# Out:
# Adjusted r2 score for training data =  0.9254599771889752

# %% [markdown]
# ####  since r2 score for training data is 93.20% so model performance is very good for training data
# ####  since there is very less difference in R2 score and Adjusted R2 score in training data so there is no unimportant features

# %%
print('intercept:', LR.intercept_) ## c value
# Out:
# intercept: -0.015982587068424904

# %%
print('slope:', LR.coef_) ## m values
# Out:
# slope: [0.89319644 0.00142817 0.07517208]

# %% [markdown]
# ##  Insights of the data set

# %%
## Since model perform well with the training as well as testing data, So our model is Generalize MODEL
## There is low Bias and low Variance
